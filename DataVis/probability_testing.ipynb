# %%
from extracted_data_from_paper import *
import scipy.stats as sps
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(exp_init11mm.d_prob_dist_bin_centers*1e6, exp_init11mm.d_prob_density*1e-6, label = "exp 11mm")
normal_y = sps.norm.pdf(exp_init11mm.d_prob_dist_bin_centers*1e6, 150, 10)
normal_y2 = sps.norm.pdf(exp_init11mm.d_prob_dist_bin_centers*1e6, 135, 5)
# plt.plot(exp_init11mm.d_prob_dist_bin_centers*1e6, normal_y)
plt.plot(exp_init11mm.d_prob_dist_bin_centers*1e6, normal_y2)
weight_exp = 0.7
# plt.plot(exp_init11mm.d_prob_dist_bin_centers*1e6, normal_y*(1-weight_exp) + exp_init11mm.d_prob_density*1e-6*weight_exp)
plt.plot(exp_init11mm.d_prob_dist_bin_centers*1e6, normal_y2*(1-weight_exp) + exp_init11mm.d_prob_density*1e-6*weight_exp)
plt.xlabel(r"$d[\mu m]$")
plt.ylabel(r"$PDF$")
plt.legend()
# plt.yscale("log")
# plt.ylim([1e-7, 1e-1])
# print(normal_y2*(1-weight_exp) + exp_init11mm.d_prob_density*1e-6*weight_exp)
print(np.array2string(exp_init11mm.d_prob_dist_bin_centers*1e6, separator=', ').replace('[', '{').replace(']', '}'))
# Out:
# { 13.39272226,  13.35972943,  14.10889908,  14.83380929,  15.55677876,
#   16.30400765,  15.51893405,  17.01533258,  16.5965956 ,  18.46321226,
#   19.58939267,  19.94214401,  20.30848062,  21.05279838,  21.79129388,
#   22.53367088,  23.27604789,  25.14751643,  28.52799842,  29.26746429,
#   30.01275242,  31.89295436,  35.3219552 ,  37.94356377,  40.21145062,
#   41.73599009,  43.26441107,  44.40805827,  46.66138947,  47.04907438,
#   48.55711744,  49.32084274,  49.71337954,  50.84538221,  51.6139594 ,
#   54.63877892,  56.16040726,  58.43993863,  60.3317851 ,  62.6103461 ,
#   66.40180205,  69.05058118,  72.83233335,  72.46793749,  75.49469776,
#   83.04752796,  89.84730701,  94.7465062 ,  99.27160576, 101.14016317,
#  102.25663981, 104.48668196, 105.59927709, 107.0840311 , 107.07238657,
#  107.81573395, 108.17721868, 108.91959569, 109.66294307, 109.65129854,
#  110.01763516, 110.76195292, 111.50821143, 112.25544032, 113.37579847,
# ...
